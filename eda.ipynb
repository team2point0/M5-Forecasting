# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
calendar_path = os.path.join(os.getcwd(), 'data', 'calendar.csv')
trainDF_path = os.path.join(os.getcwd(), 'data', 'sales_train_validation.csv')
pricesDF_path = os.path.join(os.getcwd(), 'data', 'sell_prices.csv')

df = pd.read_csv(trainDF_path)
calendarDF = pd.read_csv(calendar_path)

# %%
df
# Out:
#                                   id        item_id    dept_id   cat_id  \
# 0      HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1      HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2      HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3      HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4      HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                              ...            ...        ...      ...
# 30485    FOODS_3_823_WI_3_validation    FOODS_3_823    FOODS_3    FOODS
# 30486    FOODS_3_824_WI_3_validation    FOODS_3_824    FOODS_3    FOODS
# 30487    FOODS_3_825_WI_3_validation    FOODS_3_825    FOODS_3    FOODS
# 30488    FOODS_3_826_WI_3_validation    FOODS_3_826    FOODS_3    FOODS
# 30489    FOODS_3_827_WI_3_validation    FOODS_3_827    FOODS_3    FOODS
#
#       store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  \
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(df.groupby(['cat_id']).sum().transpose())
plt.show()

# %%
df.groupby(['cat_id']).sum()
# Out:
#              d_1    d_2    d_3    d_4    d_5    d_6    d_7    d_8    d_9  \
# cat_id
# FOODS      23178  22758  17174  18878  14603  22093  20490  27751  24862
# HOBBIES     3764   3357   2682   2669   1814   3220   2944   3986   2899
# HOUSEHOLD   5689   5634   3927   3865   2729   3898   4576   6195   4975
#
#             d_10  ...  d_1904  d_1905  d_1906  d_1907  d_1908  d_1909  d_1910  \
# cat_id            ...
# FOODS      18901  ...   28682   32007   34497   26151   24948   23632   23317
# HOBBIES     2615  ...    3786    4634    4820    3323    3787    3472    3353
# HOUSEHOLD   4056  ...    9321   11721   12323    8585    8835    8239    8363
#
#            d_1911  d_1912  d_1913
# cat_id
# FOODS       26704   31927   32654
# HOBBIES      4085    4787    4683
# HOUSEHOLD    9728   12248   12458
#
# [3 rows x 1913 columns]

# %%
df.groupby(['cat_id']).sum().transpose().sort_values(ascending=False, by=['FOODS']).head(50)
# Out:
# cat_id  FOODS  HOBBIES  HOUSEHOLD
# d_1864  38547     4879      13792
# d_1898  38334     4739      13267
# d_1892  37633     4903      13889
# d_1835  37412     5097      12531
# d_954   37186     4095      10459
# d_1884  37135     4476      12252
# d_1899  36446     4525      12885
# d_1709  36094     4930      13663
# d_961   35849     4047      11074
# d_1617  35834     5360      12960
# d_1807  35798     4836      12246
# d_1842  35686     4965      13064
# d_1136  35651     3678      10761
# d_1710  35413     4879      12603
# d_1863  35200     4636      12486
# d_1164  35030     3548      10212
# d_1654  34965     4593      12403
# d_736   34887     5210      10935
# d_1870  34734     4810      13167
# d_1871  34710     4229      12482
# d_435   34587     3757       7294
# d_953   34533     2625      10442
# d_1599  34524     3819       9237
# d_1906  34497     4820      12323
# d_982   34435     4096      11357
# d_960   34404     4049      10713
# ...

# %%
calendarDF
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2
# 2     2011-01-31     11101     Monday     3      1  2011     d_3
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# ...          ...       ...        ...   ...    ...   ...     ...
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969
#
#       event_name_1 event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  \
# 0              NaN          NaN           NaN          NaN        0        0
# ...

# %%
print(calendarDF.event_name_1.unique())
print(calendarDF.event_type_1.unique())
print(calendarDF.event_name_2.unique())
print(calendarDF.event_type_2.unique())
# Out:
# [nan 'SuperBowl' 'ValentinesDay' 'PresidentsDay' 'LentStart' 'LentWeek2'
#  'StPatricksDay' 'Purim End' 'OrthodoxEaster' 'Pesach End' 'Cinco De Mayo'
#  "Mother's day" 'MemorialDay' 'NBAFinalsStart' 'NBAFinalsEnd'
#  "Father's day" 'IndependenceDay' 'Ramadan starts' 'Eid al-Fitr'
#  'LaborDay' 'ColumbusDay' 'Halloween' 'EidAlAdha' 'VeteransDay'
#  'Thanksgiving' 'Christmas' 'Chanukah End' 'NewYear' 'OrthodoxChristmas'
#  'MartinLutherKingDay' 'Easter']
# [nan 'Sporting' 'Cultural' 'National' 'Religious']
# [nan 'Easter' 'Cinco De Mayo' 'OrthodoxEaster' "Father's day"]
# [nan 'Cultural' 'Religious']

# %%
calendarDF.iloc[1859:1880,:]
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 1859  2016-03-02     11605  Wednesday     5      3  2016  d_1860
# 1860  2016-03-03     11605   Thursday     6      3  2016  d_1861
# 1861  2016-03-04     11605     Friday     7      3  2016  d_1862
# 1862  2016-03-05     11606   Saturday     1      3  2016  d_1863
# 1863  2016-03-06     11606     Sunday     2      3  2016  d_1864
# 1864  2016-03-07     11606     Monday     3      3  2016  d_1865
# 1865  2016-03-08     11606    Tuesday     4      3  2016  d_1866
# 1866  2016-03-09     11606  Wednesday     5      3  2016  d_1867
# 1867  2016-03-10     11606   Thursday     6      3  2016  d_1868
# 1868  2016-03-11     11606     Friday     7      3  2016  d_1869
# 1869  2016-03-12     11607   Saturday     1      3  2016  d_1870
# 1870  2016-03-13     11607     Sunday     2      3  2016  d_1871
# 1871  2016-03-14     11607     Monday     3      3  2016  d_1872
# ...
